# %% [markdown]
# <a href="https://colab.research.google.com/github/eyu10/SQL-Project/blob/main/API_ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# !pip install pymysql
# !pip install mysqlclient

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
import requests  # Library to make HTTP requests
import json  # Library to work with JSON data

# Base URL for the BallDontLie API
api_url = "https://api.balldontlie.io/v1/players"

# Authorization header with the correct format (replace with your actual API key)
api_key = "ff198301-a2bc-4d86-84b7-9af3a0bcbe43"
headers = {"Authorization": f"{api_key}"}

# %%
params = {
    "per_page": 100  # Number of results per page
}

# Initialize an empty list to store all players
players = []

# Fetch 10 pages to get all 1000 players
for page in range(1, 11):  # Adjust page range to ensure complete data retrieval
    params["page"] = page  # Set the current page

    response = requests.get(api_url, headers=headers, params=params)  # Make the API request

    if response.status_code == 200:  # Ensure the request was successful
        data = response.json()
        players.extend(data["data"])  # Add the data to the players list
    else:
        print(f"Failed to fetch page {page}. Status code: {response.status_code}")

# Display total players fetched
print(f"Total players fetched: {len(players)}")
# Out:
# Total players fetched: 1000

# %%
players = []

params = {
    "per_page": 100
}

for cursor in range(0, 100, 100):
  print(f"cursor: {cursor}")

  params["cursor"] = cursor

  request = requests.get(api_url, headers=headers, params=params)

  if request.status_code == 200:  # Check if the request was successful
    response = request.json()
    players.extend(response["data"])
# Out:
# cursor: 0

# %%
len(players)
# Out:
# 100

# %%
for player in players:
  print(player)
  print(player['first_name'])
# Out:
# {'id': 1, 'first_name': 'Alex', 'last_name': 'Abrines', 'position': 'G', 'height': '6-6', 'weight': '190', 'jersey_number': '8', 'college': 'FC Barcelona', 'country': 'Spain', 'draft_year': 2013, 'draft_round': 2, 'draft_number': 32, 'team': {'id': 21, 'conference': 'West', 'division': 'Northwest', 'city': 'Oklahoma City', 'name': 'Thunder', 'full_name': 'Oklahoma City Thunder', 'abbreviation': 'OKC'}}
# Alex
# {'id': 2, 'first_name': 'Jaylen', 'last_name': 'Adams', 'position': 'G', 'height': '6-0', 'weight': '225', 'jersey_number': '10', 'college': 'St. Bonaventure', 'country': 'USA', 'draft_year': None, 'draft_round': None, 'draft_number': None, 'team': {'id': 1, 'conference': 'East', 'division': 'Southeast', 'city': 'Atlanta', 'name': 'Hawks', 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL'}}
# Jaylen
# ...

# %%
# Make the API request
response = requests.get(api_url, headers=headers, params=params)

print(response.json())
# Out:
# {'data': [{'id': 1, 'first_name': 'Alex', 'last_name': 'Abrines', 'position': 'G', 'height': '6-6', 'weight': '190', 'jersey_number': '8', 'college': 'FC Barcelona', 'country': 'Spain', 'draft_year': 2013, 'draft_round': 2, 'draft_number': 32, 'team': {'id': 21, 'conference': 'West', 'division': 'Northwest', 'city': 'Oklahoma City', 'name': 'Thunder', 'full_name': 'Oklahoma City Thunder', 'abbreviation': 'OKC'}}, {'id': 2, 'first_name': 'Jaylen', 'last_name': 'Adams', 'position': 'G', 'height': '6-0', 'weight': '225', 'jersey_number': '10', 'college': 'St. Bonaventure', 'country': 'USA', 'draft_year': None, 'draft_round': None, 'draft_number': None, 'team': {'id': 1, 'conference': 'East', 'division': 'Southeast', 'city': 'Atlanta', 'name': 'Hawks', 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL'}}, {'id': 3, 'first_name': 'Steven', 'last_name': 'Adams', 'position': 'C', 'height': '6-11', 'weight': '265', 'jersey_number': '12', 'college': 'Pittsburgh', 'country': 'New Zealand', 'd
# ...

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"data":[{"id":1,"first_name":"Alex","last_name":"Abrines","position":"G","height":"6-6","weight":"190","jersey_number":"8","college":"FC Barcelona","country":"Spain","draft_year":2013,"draft_round":2,"draft_number":32,"team":{"id":21,"conference":"West","division":"Northwest","city":"Oklahoma City","name":"Thunder","full_name":"Oklahoma City Thunder","abbreviation":"OKC"}},{"id":2,"first_name":"Jaylen","last_name":"Adams","position":"G","height":"6-0","weight":"225","jersey_number":"10","college":"St. Bonaventure","country":"USA","draft_year":null,"draft_round":null,"draft_number":null,"team":{"id":1,"conference":"East","division":"Southeast","city":"Atlanta","name":"Hawks","full_name":"Atlanta Hawks","abbreviation":"ATL"}},{"id":3,"first_name":"Steven","last_name":"Adams","position":"C","height":"6-11","weight":"265","jersey_number":"12","college":"Pittsburgh","country":"New Zealand","draft_year":2013,"draft_round":1,"draft_number":12,"team":{"id":11,"conference":"West","division"
# ...

# %%
json.loads(response.text)
# Out:
# {'data': [{'id': 1,
#    'first_name': 'Alex',
#    'last_name': 'Abrines',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '190',
#    'jersey_number': '8',
#    'college': 'FC Barcelona',
#    'country': 'Spain',
#    'draft_year': 2013,
#    'draft_round': 2,
#    'draft_number': 32,
#    'team': {'id': 21,
#     'conference': 'West',
#     'division': 'Northwest',
#     'city': 'Oklahoma City',
#     'name': 'Thunder',
#     'full_name': 'Oklahoma City Thunder',
#     'abbreviation': 'OKC'}},
#   {'id': 2,
#    'first_name': 'Jaylen',
#    'last_name': 'Adams',
#    'position': 'G',
#    'height': '6-0',
#    'weight': '225',
#    'jersey_number': '10',
#    'college': 'St. Bonaventure',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team': {'id': 1,
#     'conference': 'East',
#     'division': 'Southeast',
#     'city': 'Atlanta',
#     'name': 'Hawks',
#     'full_name': 'Atlanta Hawks',
# ...

# %%
api_response = json.loads(response.text)

# %%
type(api_response)
# Out:
# dict

# %%
api_response['data']
# Out:
# [{'id': 1,
#   'first_name': 'Alex',
#   'last_name': 'Abrines',
#   'position': 'G',
#   'height': '6-6',
#   'weight': '190',
#   'jersey_number': '8',
#   'college': 'FC Barcelona',
#   'country': 'Spain',
#   'draft_year': 2013,
#   'draft_round': 2,
#   'draft_number': 32,
#   'team': {'id': 21,
#    'conference': 'West',
#    'division': 'Northwest',
#    'city': 'Oklahoma City',
#    'name': 'Thunder',
#    'full_name': 'Oklahoma City Thunder',
#    'abbreviation': 'OKC'}},
#  {'id': 2,
#   'first_name': 'Jaylen',
#   'last_name': 'Adams',
#   'position': 'G',
#   'height': '6-0',
#   'weight': '225',
#   'jersey_number': '10',
#   'college': 'St. Bonaventure',
#   'country': 'USA',
#   'draft_year': None,
#   'draft_round': None,
#   'draft_number': None,
#   'team': {'id': 1,
#    'conference': 'East',
#    'division': 'Southeast',
#    'city': 'Atlanta',
#    'name': 'Hawks',
#    'full_name': 'Atlanta Hawks',
#    'abbreviation': 'ATL'}},
#  {'id': 3,
# ...

# %%
player_info = api_response['data']

# %%
type(players)
# Out:
# list

# %%
# Creating the empty dictionary
players = {
    'id': [],              # BigInt
    'first_name': [],      # Text
    'last_name': [],       # Text
    'position': [],        # Text
    'height': [],          # Text
    'weight': [],          # Text
    'jersey_number': [],   # Text
    'college': [],         # Text
    'country': [],         # Text
    'draft_year': [],      # Double
    'draft_round': [],     # Double
    'draft_number': [],    # Double
    'team': []             # Text
}




# Looping through the players list to populate the dictionary
for player in player_info:
    players['id'].append(player['id'])
    players['first_name'].append(player['first_name'])
    players['last_name'].append(player['last_name'])
    players['position'].append(player['position'])
    players['height'].append(player['height'])
    players['weight'].append(player['weight'])
    players['jersey_number'].append(player['jersey_number'])
    players['college'].append(player['college'])
    players['country'].append(player['country'])
    players['draft_year'].append(player['draft_year'])
    players['draft_round'].append(player['draft_round'])
    players['draft_number'].append(player['draft_number'])
    players['team'].append(player['team']['name'])

# %%
type(players)
# Out:
# dict

# %%
players_df = pd.DataFrame(players)  # Convert to DataFrame


players_df.head()
# Out:
#    id first_name      last_name position height weight jersey_number  \
# 0   1       Alex        Abrines        G    6-6    190             8
# 1   2     Jaylen          Adams        G    6-0    225            10
# 2   3     Steven          Adams        C   6-11    265            12
# 3   4        Bam        Adebayo      C-F    6-9    255            13
# 4   5   DeVaughn  Akoon-Purcell      G-F    6-5    201            44
#
#            college              country  draft_year  draft_round  \
# 0     FC Barcelona                Spain      2013.0          2.0
# 1  St. Bonaventure                  USA         NaN          NaN
# 2       Pittsburgh          New Zealand      2013.0          1.0
# 3         Kentucky                  USA      2017.0          1.0
# 4   Illinois State  Trinidad and Tobago      2016.0          NaN
#
#    draft_number     team
# 0          32.0  Thunder
# 1           NaN    Hawks
# 2          12.0  Rockets
# 3          14.0     Heat
# 4           NaN  Nuggets

# %%
players_df.to_csv('players', index=False)

# %%
from sqlalchemy import create_engine  # Import SQLAlchemy's engine creation module

# Database connection details (ensure to replace with your actual credentials)
db_host = "nbaplayers.ch7mhjpbrvtl.us-east-1.rds.amazonaws.com"  # AWS RDS host
db_username = "admin"  # Admin username
db_password = "Golf23!!!"  # Database password
db_schema = "/sql_project"  # Schema (database) name
db_port = 3306  # Default MySQL port

# Create the SQLAlchemy engine for MySQL
engine = create_engine(
    f"mysql+pymysql://{db_username}:{db_password}@{db_host}{db_schema}"
)  # Create the connection string for SQLAlchemy

# %%
players_df.to_sql('player_info', engine, if_exists='replace', index=False)
# Out:
# 100
